# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

Model_Accuracy = [89.74, 86, 92.31, 90, 92.31, 92, 87.18, 94, 97.4, 92]
NoNo = [36, 42, 36, 45, 34, 45, 34, 45, 36, 45]
NoYes = [0, 4, 0, 1, 2, 1, 2, 1, 0, 1]
YesNo = [2, 3, 2, 4, 1, 3, 3, 2, 3, 3]
YesYes = [1, 1, 1, 0, 2, 1, 0, 2, 0, 1]
Pct_NoNo = [1.00, .91, 1.00, .98, .94, .98, .94, .98, 1.00, .98]
Pct_NoYes = [0, .09, 0, .02, .06, .02, .06, .02, 0, .02]
Pct_YesNo = [0.67, .75, 0.67, 1.00, .33, .75, 1.00, .50, 1.00, .75]
Pct_YesYes = [0.33, .25, 0.33, 0, .67, .25, 0, .50, 0, .25]
labels = ["DT1", "DT2", "RF1", "RF2", "LR1", "LR2", "SVM1", "SVM2", "KNN1", "KNN2"]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, NoNo, width, label='True No', color='blue')
rects2 = ax.bar(x + width/2, YesYes, width, label='True Yes', color='purple')
rects3 = ax.bar(x - width/2, NoYes, width, label='False Yes', bottom=NoNo, color='orange')
rects4 = ax.bar(x + width/2, YesNo, width, label='False No', bottom=YesYes, color='yellow')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Model')
ax.set_title('Model Predictions by Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

fig.tight_layout()

plt.show()

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Pct_NoNo, width, label='True No', color='blue')
rects2 = ax.bar(x + width/2, Pct_YesYes, width, label='True Yes', color='purple')
rects3 = ax.bar(x - width/2, Pct_NoYes, width, label='False Yes', bottom=Pct_NoNo, color='orange')
rects4 = ax.bar(x + width/2, Pct_YesNo, width, label='False No', bottom=Pct_YesYes, color='yellow')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Model')
ax.set_title('Model Predictions by Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='center right')

fig.tight_layout()

plt.show()

# %%
# Plot Test/Train Dataset Comparison
labels = ['Dataset 1', 'Dataset 2']
rows = [154, 198]
CAD_yes = [10,15]
Train_yes = [7, 11]
Test_yes = [3,4]
Train_no = [108,137]
Test_no = [36, 46]
Parameters = [24,14]

x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Train_yes, width, label='Train Yes', color='orange')
rects2 = ax.bar(x + width/2, Test_yes, width, label='Test Yes', color='yellow')
rects3 = ax.bar(x - width/2, Train_no, width, label='Train No', bottom=Train_yes, color='blue')
rects4 = ax.bar(x + width/2, Test_no, width, label='Test No', bottom=Test_yes, color='purple')
rects5 = ax.bar(x + width*3/2, Parameters, width, label='Params', color='gray')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Dataset')
ax.set_title('Dataset Train/Test Comparison')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 4),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)


fig.tight_layout()

plt.show()
